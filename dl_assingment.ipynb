# %%
from tensorflow import keras
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense,LSTM
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Embedding,LSTM, Dense, SimpleRNN
import matplotlib.pyplot as plt

# %%
# Set the maximum number of words to consider in the reviews
max_words = 10000

# Load the IMDB dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_words)

# Pad the sequences to have the same length
max_length = 500
x_train = sequence.pad_sequences(x_train, maxlen=max_length)
x_test = sequence.pad_sequences(x_test, maxlen=max_length)

# %% [markdown]
# #gru

# %%
model = Sequential()
model.add(Embedding(max_words, 32, input_length=max_length))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
batch_size = 128
epochs = 5
history=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)

# Evaluate the model on the test set
# Out:
# Epoch 1/5
# 157/157 [==============================] - 62s 377ms/step - loss: 0.5375 - accuracy: 0.7063 - val_loss: 0.3479 - val_accuracy: 0.8536
# Epoch 2/5
# 157/157 [==============================] - 59s 374ms/step - loss: 0.2816 - accuracy: 0.8860 - val_loss: 0.3168 - val_accuracy: 0.8684
# Epoch 3/5
# 157/157 [==============================] - 59s 375ms/step - loss: 0.2051 - accuracy: 0.9255 - val_loss: 0.3416 - val_accuracy: 0.8590
# Epoch 4/5
# 157/157 [==============================] - 57s 365ms/step - loss: 0.1669 - accuracy: 0.9417 - val_loss: 0.3459 - val_accuracy: 0.8706
# Epoch 5/5
# 157/157 [==============================] - 56s 360ms/step - loss: 0.1316 - accuracy: 0.9564 - val_loss: 0.3925 - val_accuracy: 0.8662

# %% [markdown]
# #lstm

# %%
model1=Sequential()
model1.add(Embedding(max_words,32,input_length=max_length))
model1.add(LSTM(32))
model.add(Dense(1, activation='sigmoid'))

model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


batch_size = 128
epochs = 5
history1=model1.fit(x_train, y_train, batch_size=128, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/5
# 157/157 [==============================] - 66s 400ms/step - loss: 2.1483 - accuracy: 6.0000e-04 - val_loss: 1.3451 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 157/157 [==============================] - 63s 400ms/step - loss: 1.3363 - accuracy: 0.0000e+00 - val_loss: 1.1360 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 157/157 [==============================] - 63s 402ms/step - loss: 1.1079 - accuracy: 0.1107 - val_loss: 1.0230 - val_accuracy: 0.1914
# Epoch 4/5
# 157/157 [==============================] - 62s 394ms/step - loss: 1.1717 - accuracy: 0.1658 - val_loss: 0.9604 - val_accuracy: 0.3470
# Epoch 5/5
# 157/157 [==============================] - 62s 399ms/step - loss: 0.9097 - accuracy: 0.3214 - val_loss: 0.9407 - val_accuracy: 0.4010

# %% [markdown]
# #RNN

# %%
model2=Sequential()
model2.add(Embedding(max_words,100,input_length=max_length))
model2.add(LSTM(32))
model2.add(Dense(1, activation='sigmoid'))

model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history3=model2.fit(x_train,y_train,epochs=5,batch_size=128,validation_split=0.2)
# Out:
# Epoch 1/5
# Exception ignored in: <function _xla_gc_callback at 0x7ab3ffab5a20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 98, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 157/157 [==============================] - 206s 751ms/step - loss: 0.4629 - accuracy: 0.7793 - val_loss: 0.3363 - val_accuracy: 0.8574
# Epoch 2/5
# 157/157 [==============================] - 118s 755ms/step - loss: 0.2417 - accuracy: 0.9093 - val_loss: 0.2923 - val_accuracy: 0.8834
# Epoch 3/5
# 157/157 [==============================] - 119s 757ms/step - loss: 0.1820 - accuracy: 0.9356 - val_loss: 0.3269 - val_accuracy: 0.8654
# Epoch 4/5
# 157/157 [==============================] - 117s 745ms/step - loss: 0.1275 - accuracy: 0.9585 - val_loss: 0.3450 - val_accuracy: 0.8640
# Epoch 5/5
# 157/157 [==============================] - 117s 748ms/step - loss: 0.1341 - accuracy: 0.9539 - val_loss: 0.3937 - val_accuracy: 0.8690

# %% [markdown]
# #graph

# %%
import matplotlib.pyplot as plt



# Extract accuracy values from the training history
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Number of epochs
epochs = range(1, len(train_acc) + 1)

# Create the plot
plt.plot(epochs, train_acc, 'b', label='Training Accuracy gru')
plt.plot(epochs, val_acc, 'bo', label='Validation Accuracy gru')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# Load the IMDb dataset
max_features = 10000
max_len = 500
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# Create models
def create_model(model_type):
    model = Sequential()
    model.add(Embedding(max_features, 32, input_length=max_len))
    if model_type == 'LSTM':
        model.add(LSTM(32))
    elif model_type == 'GRU':
        model.add(GRU(32))
    elif model_type == 'RNN':
        model.add(SimpleRNN(32))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Train models and collect history
model_types = ['LSTM', 'GRU', 'RNN']
histories = []

plt.figure(figsize=(10, 6))

for model_type in model_types:
    model = create_model(model_type)
    history = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2, verbose=1)
    plt.plot(history.history['val_accuracy'], label=f'{model_type} Validation Accuracy')

plt.title('Comparison of Model Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 157/157 [==============================] - 66s 405ms/step - loss: 0.5183 - accuracy: 0.7402 - val_loss: 0.4593 - val_accuracy: 0.7850
# Epoch 2/5
# 157/157 [==============================] - 61s 389ms/step - loss: 0.2991 - accuracy: 0.8837 - val_loss: 0.3186 - val_accuracy: 0.8718
# Epoch 3/5
# 157/157 [==============================] - 61s 389ms/step - loss: 0.2024 - accuracy: 0.9263 - val_loss: 0.3003 - val_accuracy: 0.8852
# Epoch 4/5
# 157/157 [==============================] - 61s 390ms/step - loss: 0.1596 - accuracy: 0.9470 - val_loss: 0.3233 - val_accuracy: 0.8772
# Epoch 5/5
# 157/157 [==============================] - 62s 392ms/step - loss: 0.1191 - accuracy: 0.9622 - val_loss: 0.3351 - val_accuracy: 0.8774
# Epoch 1/5
# 157/157 [==============================] - 63s 378ms/step - loss: 0.5788 - accuracy: 0.6833 - val_loss: 0.4224 - val_accuracy: 0.8028
# Epoch 2/5
# 157/157 [==============================] - 59s 375ms/step - loss: 0.3140 - accuracy: 0.8694 - val_loss: 0.3780 - val_accuracy: 0.8352
# Epoch 3/5
# 157/157 [==============================] - 61s 392ms/step - loss: 0.2134 - accuracy: 0.9204 - val_loss: 0.3342 - val_accuracy: 0.8712
# Epoch 4/5
# 157/157 [==============================] - 60s 380ms/step - loss: 0.1725 - accuracy: 0.9386 - val_loss: 0.3467 - val_accuracy: 0.8648
# Epoch 5/5
# 157/157 [==============================] - 61s 390ms/step - loss: 0.1403 - accuracy: 0.9514 - val_loss: 0.3766 - val_accuracy: 0.8538
# Epoch 1/5
# 157/157 [==============================] - 32s 193ms/step - loss: 0.6193 - accuracy: 0.6543 - val_loss: 0.4584 - val_accuracy: 0.7958
# Epoch 2/5
# 157/157 [==============================] - 31s 196ms/step - loss: 0.3743 - accuracy: 0.8416 - val_loss: 0.3927 - val_accuracy: 0.8280
# Epoch 3/5
# 157/157 [==============================] - 29s 183ms/step - loss: 0.2858 - accuracy: 0.8855 - val_loss: 0.3974 - val_accuracy: 0.8366
# Epoch 4/5
# 157/157 [==============================] - 29s 184ms/step - loss: 0.1942 - accuracy: 0.9284 - val_loss: 0.3942 - val_accuracy: 0.8422
# Epoch 5/5
# 157/157 [==============================] - 30s 191ms/step - loss: 0.1032 - accuracy: 0.9679 - val_loss: 0.4450 - val_accuracy: 0.8340
