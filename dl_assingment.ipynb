# %% [markdown]
# <a href="https://colab.research.google.com/github/dheeraj997/dl_assignment/blob/main/dl_assingment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense,LSTM
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Embedding,LSTM, Dense, SimpleRNN
import matplotlib.pyplot as plt

# Set the maximum number of words to consider in the reviews
max_words = 10000

# Load the IMDB dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_words)

# Pad the sequences to have the same length
max_length = 500
x_train = sequence.pad_sequences(x_train, maxlen=max_length)
x_test = sequence.pad_sequences(x_test, maxlen=max_length)
# Out:
# ...
# 17464789/17464789 [==============================] - 1s 0us/step

# %% [markdown]
# #gru

# %%
model1 = Sequential()
model1.add(Embedding(max_words, 32, input_length=max_length))
model1.add(GRU(32))
model1.add(Dense(1, activation='sigmoid'))

model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
batch_size = 128
epochs = 5
#history=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)

# Evaluate the model on the test set

# %% [markdown]
# #lstm

# %%
model2=Sequential()
model2.add(Embedding(max_words,32,input_length=max_length))
model2.add(LSTM(32))
model2.add(Dense(1, activation='sigmoid'))

model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


# batch_size = 128
# epochs = 5
# history1=model1.fit(x_train, y_train, batch_size=128, epochs=epochs, validation_split=0.2)

# %% [markdown]
# #RNN

# %%
model3=Sequential()
model3.add(Embedding(max_words,32,input_length=max_length))
model3.add(LSTM(32))
model3.add(Dense(1, activation='sigmoid'))

model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# history3=model2.fit(x_train,y_train,epochs=5,batch_size=128,validation_split=0.2)

# %% [markdown]
# #graph

# %%
import matplotlib.pyplot as plt

# Create an empty list to store training histories
histories = []

# Define and train the models
history1 = model1.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2)
histories.append(history1)

history2 = model2.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2)
histories.append(history2)

history3 = model3.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2)
histories.append(history3)


plt.figure(figsize=(10, 6))

for i, history in enumerate(histories):
    plt.plot(history.history['val_accuracy'], label=f'Model {i+1} Validation Accuracy')

plt.title('Comparison of Model Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 157/157 [==============================] - 67s 410ms/step - loss: 0.5328 - accuracy: 0.7089 - val_loss: 0.3340 - val_accuracy: 0.8580
# Epoch 2/5
# 157/157 [==============================] - 65s 411ms/step - loss: 0.2686 - accuracy: 0.8922 - val_loss: 0.3200 - val_accuracy: 0.8688
# Epoch 3/5
# 157/157 [==============================] - 64s 406ms/step - loss: 0.1901 - accuracy: 0.9291 - val_loss: 0.3294 - val_accuracy: 0.8644
# Epoch 4/5
# 157/157 [==============================] - 64s 407ms/step - loss: 0.1525 - accuracy: 0.9477 - val_loss: 0.3346 - val_accuracy: 0.8720
# Epoch 5/5
# 157/157 [==============================] - 64s 410ms/step - loss: 0.1167 - accuracy: 0.9622 - val_loss: 0.3751 - val_accuracy: 0.8646
# Epoch 1/5
# 157/157 [==============================] - 68s 411ms/step - loss: 0.5121 - accuracy: 0.7535 - val_loss: 0.3589 - val_accuracy: 0.8516
# Epoch 2/5
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# Load the IMDb dataset
max_features = 10000
max_len = 500
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# Create models
def create_model(model_type):
    model = Sequential()
    model.add(Embedding(max_features, 32, input_length=max_len))
    if model_type == 'LSTM':
        model.add(LSTM(32))
    elif model_type == 'GRU':
        model.add(GRU(32))
    elif model_type == 'RNN':
        model.add(SimpleRNN(32))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Train models and collect history
model_types = ['LSTM', 'GRU', 'RNN']
histories = []

plt.figure(figsize=(10, 6))

for model_type in model_types:
    model = create_model(model_type)
    history = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2, verbose=1)
    plt.plot(history.history['val_accuracy'], label=f'{model_type} Validation Accuracy')

plt.title('Comparison of Model Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 157/157 [==============================] - 66s 405ms/step - loss: 0.5183 - accuracy: 0.7402 - val_loss: 0.4593 - val_accuracy: 0.7850
# Epoch 2/5
# 157/157 [==============================] - 61s 389ms/step - loss: 0.2991 - accuracy: 0.8837 - val_loss: 0.3186 - val_accuracy: 0.8718
# Epoch 3/5
# 157/157 [==============================] - 61s 389ms/step - loss: 0.2024 - accuracy: 0.9263 - val_loss: 0.3003 - val_accuracy: 0.8852
# Epoch 4/5
# 157/157 [==============================] - 61s 390ms/step - loss: 0.1596 - accuracy: 0.9470 - val_loss: 0.3233 - val_accuracy: 0.8772
# Epoch 5/5
# 157/157 [==============================] - 62s 392ms/step - loss: 0.1191 - accuracy: 0.9622 - val_loss: 0.3351 - val_accuracy: 0.8774
# Epoch 1/5
# 157/157 [==============================] - 63s 378ms/step - loss: 0.5788 - accuracy: 0.6833 - val_loss: 0.4224 - val_accuracy: 0.8028
# Epoch 2/5
# ...
